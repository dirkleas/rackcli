# %% [markdown]
# ### rackcli cloud - h4x VCV Rack partial metadata resolution via rackcli cloud
#
# There are two ways to generate a full `catalog.json` for your VCV Rack installed plugins: 1) use the `File.Catalog` menu option in my [VCV Rack fork](https://github.com/dirkleas/Rack), or 2) use my [DLwigglz plugin r4xH4x module]() `catalog (partial)` button along with the [rackcli cloud](https://github.com/dirkleas/rackcloud) service via [rackcli](https://github.com/dirkleas/rackcli). Here's the lowdown on 2).
#
# Workflow to get a full `catalog.json` without forking VCV Rack:
#
# 1. one time: download and build or install the binary for DLwigglz
# 1. one time: download and install rackcli
# 1. add DLwigglz r4xH4x module to your patch, press `catalog (partial)` button
# 1. patch `catalog.partial.json` via the [rackcloud](https://github.com/dirkleas/rackcloud) or a local full `catalog.json`
#
# Always use the fullly formed, recent `catalog.json` if your hacking project requires width data -- pretty much anything dealing with layout management or patch composition requires it.

# %% [markdown]
# Here's an example of what the `catalog.partial.json` (via `catalog (partial)` button on DLwigglz r4xH4x) and augmented patch files might look like. Sample output has been truncated for covenience -- this was generated from my plugins and I've purchased almost every official module and build/installed many others, last count, alost 100 plugins!

# %%
from pprint import pprint as pp
from typing import *
from hashlib import sha256
from itertools import islice
from time import gmtime, strftime
import json, boto3

# %%
rackdir = '/Users/dirkleas/Desktop/h4x/_queue_/vcv/Rack'
catalog = json.load(open(rackdir + '/catalog.json'))
partial = json.load(open(rackdir + '/catalog.partial.json')) # DLwigglz r4xHrx output
patch = json.load(open(rackdir + '/dox.vcv'))

# %% [markdown]
# For reference, here's how one can also interact with AWS [S3](https://aws.amazon.com/s3/) given appropriate rights using the python3 [boto3](https://boto3.readthedocs.io/en/latest/https://aws.amazon.com/s3/) library. Here's an example of accessing the shared corpus (again, assuming access rights -- you'll need to set up your own Amazon AWS account).

# %%
obj = boto3.resource('s3').Object('rackcloud', 'corpus.test.json')
x = json.loads(obj.get()['Body'].read().decode('utf-8')) # read/load corpus
# pp(x)
x[strftime("%Y-%m-%d %H:%M:%S", gmtime())] = 'sup?!?!'

# obj.put(Body=str.encode(json.dumps(x))) # write
# pp(json.loads(obj.get()['Body'].read().decode('utf-8'))) # update corpus

# %% [markdown]
# Here's the model for the cloud corpus of all know plugin modules.

# %%
corpus = {'sha256(rv,ps,pv,ms)': ('rv', 'ps', 'pv', 'ms', 69)}
corpus = {'0668e58ce7a7aa49b5583aac63a2d73b2b45cf1de20efa5dc7351c4216cdd44d': ('rv', 'ps', 'pv', 'ms', 69)}
print(f'corpus model: {corpus}')
# Out:
# corpus model: {'0668e58ce7a7aa49b5583aac63a2d73b2b45cf1de20efa5dc7351c4216cdd44d': ('rv', 'ps', 'pv', 'ms', 69)}

# %% [markdown]
# Now we can "share" our fully-formed `catalog.json` with the world via the cloud service (or manually with curl) -- let's see how to generate the appropriate share request. Remember, this assumes a `catalog.json` generated via the fork, complete with width data.

# %%
def hash(rv: str, ps: str, pv: str, ms: str) -> str:
    'hash rack version, plugin slug/version, model slug'
    return(sha256(str.encode('{}|{}|{}|{}'.format(rv, ps, pv, ms))).hexdigest())

def catalog_share_corpus(catalog: Dict) -> Dict[str, Tuple]:
    'generate partial corpus from catalog for sharing with cloud, embed in rackcli'
    return({hash(catalog['applicationVersion'], p['slug'], p['version'], m['slug']): 
            (catalog['applicationVersion'], p['slug'], p['version'], m['slug'], m['width']) \
            for p in catalog['plugins'] for m in p['models']})

def patch_share_corpus(patch: Dict) -> Dict[str, Tuple]:
    'corpus request from a "r4xH4x patch" patch, embed in rackcli'
    return({hash(patch['version'], m['plugin'], m['version'], m['model']):
            (patch['version'], m['plugin'], m['version'], m['model'], m['width']) for m in patch['modules']})

corpus = catalog_share_corpus(catalog)
# corpus = patch_share_corpus(patch)
# pp(corpus)

json.dump(corpus, open('/tmp/share.json', 'w'), indent=2, ensure_ascii=False) # serialize for curl
# manual test: curl -X POST -H "Content-Type: application/json" -d @DATAFILE.JSON URL
# curl -X POST -H "Content-Type: application/json" -d @/tmp/share.json https://9k564tm679.execute-api.us-east-1.amazonaws.com/dev/share | jq
# Out:
# {'0000262960951166f8474540e81c3a8993b4d1132f97498bb3e327a70533ce20': ('0.6.1',
#                                                                       'PvC',
#                                                                       '0.6.0',
#                                                                       'TaHaSaHaN',
#                                                                       30),
#  '0011578f7c3b542292209a8f21fcd3c8926f699302bfea13f523ea3fdd604a3a': ('0.6.1',
#                                                                       'SonusModular',
#                                                                       '0.6.1',
#                                                                       'Piconoise',
#                                                                       60),
#  '00e1b0f432fb178151e9b7507ea3f328c4315845aebe17564268a06f9ac0ea32': ('0.6.1',
#                                                                       'AS',
#                                                                       '0.6.7',
#                                                                       'SignalDelay',
#                                                                       90),
#  '010a3f62c416d66a05457e12cd90dad67535539e76fcd5030c4daaef2e05e690': ('0.6.1',
#                                                                       'Bidoo',
#                                                                       '0.6.1',
#                                                                       'MOiRE',
#                                                                       225),
#  '0119d37e9fe91bfdfff414035a41125753a78f1ca4643005f263da5ca837736c': ('0.6.1',
#                                                                       'AudibleInstruments',
#                                                                       '0.6.0',
#                                                                       'Shades',
#                                                                       90),
#  '012f672caae37404c04941712582f4e2f22f51957dfd67d86f77c620509eb3ee': ('0.6.1',
#                                                                       'SonusModular',
#                                                                       '0.6.1',
#                                                                       'Bitter',
#                                                                       120),
#  '0243510d6bd1a53b1e9251f45d8f54b340b0d259542e477af2abe86c466bfad4': ('0.6.1',
#                                                                       'ML_modules',
#                                                                       '0.6.1',
#                                                                       'Evolution',
#                                                                       120),
#  '0255516f5ff4fe406623e0d6e1786b1d8a63596bf8d4486c0c2ecfa6e87ff5e8': ('0.6.1',
#                                                                       'SerialRacker',
#                                                                       '0.6.1',
#                                                                       'MidiMultiplexer',
#                                                                       150),
#  '025ce75b8bd947e805a8d7401a4271ae33de10626048f63e09920fb77918b28b': ('0.6.1',
#                                                                       'Aepelzens '
#                                                                       'Modules',
#                                                                       '0.6.0dev',
#                                                                       'Werner',
#                                                                       30),
#  '0332aef5bb8f87d7e465751084c131d4a2036a7f9b93091cc90feff5339def46': ('0.6.1',
#                                                                       'AS-Drums-n-Filters',
#                                                                       '0.6.2',
#                                                                       'Drums8x8Kicks',
#                                                                       60),
#  '033a5eb16bc1097291ccd5b50220718f614785999d9558032ef4ec3ec25d2732': ('0.6.1',
#                                                                       'ML_modules',
#                                                                       '0.6.1',
#                                                                       'OctaTrig',
#                                                                       150),
#  '039e2104593c20cd7f6a52c0dabed7190f13ab3b9020f276646265171827e2cd': ('0.6.1',
#                                                                       'AS-Drums-n-Filters',
#                                                                       '0.6.2',
#                                                                       'Drums9x9Kicks',
#                                                                       60),
#  '04540e36f93d58e7bdcf263e19b8ab53bc9ba69d32b5ea70b4d6217c16a75f1e': ('0.6.1',
#                                                                       'Blamsoft-XFXDistortionPack',
#                                                                       '0.6.0',
#                                                                       'Blamsoft-XFXGrunge',
#                                                                       90),
#  '04c7f9d74cd356f8e61d6f4e01385e10d2f66b0e63f84baf44ca1b62238c121f': ('0.6.1',
#                                                                       'modular80',
#                                                                       '0.6.0',
#                                                                       'Logistiker',
#                                                                       90),
#  '053340bf268a9da50e19d60e8cced606662f5e1dc29b026db8bc478e22c6c34f': ('0.6.1',
#                                                                       'Bidoo',
#                                                                       '0.6.1',
#                                                                       'vOId',
#                                                                       180),
#  '05ce80d56207106493230585f70970b6eb1a93b73e9c4715747d893e5e5b84e6': ('0.6.1',
#                                                                       'Bogaudio',
#                                                                       '0.6.6',
#                                                                       'Bogaudio-Noise',
#                                                                       45),
#  '062d9c924b937a75b8e38afb9306a0eb5277cc52b0b01654dae0ffbd7584cc6f': ('0.6.1',
#                                                                       'FrozenWasteland',
#                                                                       '0.6.6',
#                                                                       'BPMLFO2',
#                                                                       150),
#  '0668e58ce7a7aa49b5583aac63a2d73b2b45cf1de20efa5dc7351c4216cdd44d': ('0.6.1',
#                                                                       'Core',
#                                                                       '0.6.1',
#                                                                       'QuadMIDIToCVInterface',
#                                                                       150),
#  '06d9bc49204923cd600d31e4f1258714b5a4b57e276ab8e926f49799e394788f': ('0.6.1',
#                                                                       'AudibleInstruments',
#                                                                       '0.6.0',
#                                                                       'Blinds',
#                                                                       180),
#  '06e30b4aa17c56b4da411d717599ced2be8c9cc99dde26ae051e6addd156669e': ('0.6.1',
#                                                                       'Koralfx-Modules',
#                                                                       '0.6.9',
#                                                                       'Presetovnik',
#                                                                       240),
#  '07a3a9b6cd0e25116dae58a7041e8156dcdc62b49e2a4a273591d06fe6d674cd': ('0.6.1',
#                                                                       'KlirrFactoryM2',
#                                                                       '0.5.1.2',
#                                                                       'MorphOSC2',
#                                                                       375),
#  '07d595d8ef048bebc784a9124a516ebc4c55f604d62675684dfff0ce388dcf98': ('0.6.1',
#                                                                       'ML_modules',
#                                                                       '0.6.1',
#                                                                       'SeqSwitch',
#                                                                       120),
#  '080d85b3d80b1ca4c1b67b09f131e1432dcd05f9dc6047628bdfa9edf7941c96': ('0.6.1',
#                                                                       'Valley',
#                                                                       '0.6.3',
#                                                                       'uGraph',
#                                                                       150),
#  '085007777d5f94d7e96be06a888a3b4abb3486be2828eacfaa26cc3c3fe1b5f7': ('0.6.1',
#                                                                       'Qwelk',
#                                                                       '0.6.0',
#                                                                       'Chaos',
#                                                                       240),
#  '088bd8a727e09e343e095d96a9ade344b478fdcd029c6f4a7c6b9104c449aef6': ('0.6.1',
#                                                                       'Fundamental',
#                                                                       '0.6.0',
#                                                                       'VCF',
#                                                                       120),
#  '08a327707e7eea4e35360e9f7b1399f41cd45fec1a064d2479fc7c2ca8f8f4a6': ('0.6.1',
#                                                                       'DrumKit',
#                                                                       '0.6.0',
#                                                                       'Open '
#                                                                       'HiHat',
#                                                                       45),
#  '08c9a1ef8001dd79de87fff991257a2ab55521c60dc809cf50cf5a97742f9fe7': ('0.6.1',
#                                                                       'LOGinstruments',
#                                                                       '0.6.0',
#                                                                       'Constant',
#                                                                       120),
#  '090df5613a03bc9ee0aa53a238a9b468de352f4c472768d36d9b2cf4079459c0': ('0.6.1',
#                                                                       'JW-Modules',
#                                                                       '0.6.1',
#                                                                       'BouncyBalls',
#                                                                       720),
#  '091d28e38ffb9751b25ab2c97210ff674eea8d8c9dc27254753d1ca4362cff9b': ('0.6.1',
#                                                                       'ML_modules',
#                                                                       '0.6.1',
#                                                                       'FreeVerb',
#                                                                       90),
#  '0928a41ffdade17822ab447769eae969a3cb6d098e956da15cb0b08696149746': ('0.6.1',
#                                                                       'Southpole',
#                                                                       '0.6.0',
#                                                                       'Sssh',
#                                                                       60),
#  '094f88710e163254bd6b9db0992ee166d825327d4c85047122fec18bb9ff053e': ('0.6.1',
#                                                                       'FrozenWasteland',
#                                                                       '0.6.6',
#                                                                       'PhasedLockedLoop',
#                                                                       150),
#  '099672eaaff2d60458769121d7ad9cf2e9c2ba2bc9dc5362d3c94110acb219ca': ('0.6.1',
#                                                                       'AS-Drums-n-Filters',
#                                                                       '0.6.2',
#                                                                       'DrumsC64Kicks',
#                                                                       60),
#  '0a1b9cf2535dc3b57d7598d29bee2a9247caf3508d8dd257265ae30aac22ad2d': ('0.6.1',
#                                                                       'RJModules',
#                                                                       '0.6.0',
#                                                                       'Range',
#                                                                       150),
#  '0b15c92dea20ddc37d8eef8ee0a11e0d7c822bc1fea63cf275bc8f8d9fd7fcf6': ('0.6.1',
#                                                                       'dBiz',
#                                                                       '0.6.0',
#                                                                       'VCA530',
#                                                                       180),
#  '0bae880793a9a8ec37f174916ba3bfee745aa7f4fd4b8327eb1a12ced576443e': ('0.6.1',
#                                                                       'TheXOR',
#                                                                       '0.6.2',
#                                                                       'Attenuator',
#                                                                       120),
#  '0bb42b2d3e1c1533803c7dd4b25c5ac208e8be43996e37b497cf9eee178d2dbc': ('0.6.1',
#                                                                       'ML_modules',
#                                                                       '0.6.1',
#                                                                       'TrigSwitch3',
#                                                                       180),
#  '0c5b77a2a07682620593327beb68efe8a8a618e6f1751780044c7826dc3a4b7d': ('0.6.1',
#                                                                       'LindenbergResearch',
#                                                                       '0.6.0',
#                                                                       'BlankPanel '
#                                                                       '01',
#                                                                       270),
#  '0cb2fef43718c351930b31ccda44b88a9edeb056fa6c7e09914c2eb9a7c4ea69': ('0.6.1',
#                                                                       'AS',
#                                                                       '0.6.7',
#                                                                       'TremoloFx',
#                                                                       90),
#  '0d05852f069ed17ea59e899934264e92fa470121ea2f126bbbc992ec9f23c703': ('0.6.1',
#                                                                       'NonLinearInstruments',
#                                                                       '0.6.0',
#                                                                       'LuciControlINFL',
#                                                                       375),
#  '0d26816d7029b5c4d030d588c61227c99442fa2cd25f19aafcc3f0882290b981': ('0.6.1',
#                                                                       'UnfilteredVolume1',
#                                                                       '0.6.0',
#                                                                       'Dent '
#                                                                       'Crusher',
#                                                                       180),
#  '0d6b373ee7ac75ab8428bcc73971f78b96fa77577cf7cb7f4d51ee392f85711a': ('0.6.1',
#                                                                       'Bidoo',
#                                                                       '0.6.1',
#                                                                       'pErCO',
#                                                                       120),
#  '0d97fa9f908f3ba3c11606190287034124c712d4d7cb7c2a7f6124c8a3631a35': ('0.6.1',
#                                                                       'alto777_LFSR',
#                                                                       '0.6.21',
#                                                                       'cheapFX',
#                                                                       105),
#  '0de01b7053e9b38eca13ff3d9322c6b2d930f84a6daed832c039f2af64067b07': ('0.6.1',
#                                                                       'Ohmer',
#                                                                       '0.6.4',
#                                                                       'SplitterModule',
#                                                                       30),
#  '0e864626e4206c68dd4ae3f7b948e19d7628fb1ee0cd0079122f24196a33b4fa': ('0.6.1',
#                                                                       'squinkylabs-plug1',
#                                                                       '0.6.3',
#                                                                       'squinkylabs-vocalfilter',
#                                                                       180),
#  '0eb3e45cb5dee1d5000489caded1e15376525bc6b2cfe622f7ffd5f3eafbac28': ('0.6.1',
#                                                                       'LindenbergResearch',
#                                                                       '0.6.0',
#                                                                       'LPFilter24dB',
#                                                                       150),
#  '0eb7be0fa2908e2eab01c2ac47628a2c4578be96d81ba65f75beb7f3b12dabd2': ('0.6.1',
#                                                                       'Koralfx-Modules',
#                                                                       '0.6.9',
#                                                                       'Nullovnik6',
#                                                                       90),
#  '0eb8183b76b94e204c0ad94a1280bfe9d38dedbcfdd1505260281355e44be4ac': ('0.6.1',
#                                                                       'VultModules',
#                                                                       '0.6.3',
#                                                                       'UtilBypass',
#                                                                       60),
#  '0f4d670279d1ac28da2a17b5f100e518be9ca823f1ab5c0f2bee946df6d4c42c': ('0.6.1',
#                                                                       'VultModules',
#                                                                       '0.6.3',
#                                                                       'BlackPanel',
#                                                                       90),
#  '0f518975048363ebe185a27be9a3e1720761ab8eee69dbd496519cbf16e9c289': ('0.6.1',
#                                                                       'NYSTHI',
#                                                                       '0.6.3',
#                                                                       'TIMEX',
#                                                                       120),
#  '0fb8c4d95be930b3c3e8e04f341314a9e87753d1bb785dd8b0d065731d674f53': ('0.6.1',
#                                                                       'Autodafe '
#                                                                       '- REDs',
#                                                                       '0.6.0',
#                                                                       '[H]ATS',
#                                                                       240),
#  '108d74b32ef67e95a644e9607b44522d4f5b07022748a95f2e5077546f4f0367': ('0.6.1',
#                                                                       'KlirrFactoryC',
#                                                                       '0.5.1.2',
#                                                                       'BitOSC',
#                                                                       225),
#  '10a87bce0520c655bef642517276205632cecb6ea5a1b38fa9617adc0d392bae': ('0.6.1',
#                                                                       'AS',
#                                                                       '0.6.7',
#                                                                       'LaunchGate',
#                                                                       90),
#  '10b1a1e036a9ae306a41581d76626399af20032415deaee345d7c747cd476f69': ('0.6.1',
#                                                                       'Southpole',
#                                                                       '0.6.0',
#                                                                       'Blank8HP',
#                                                                       120),
#  '10d29cce541191fe0e3796497d33d13acbac8e14eb6a4a85a38f7f084577cde6': ('0.6.1',
#                                                                       'SubmarineFree',
#                                                                       '0.6.3',
#                                                                       'XF-102',
#                                                                       180),
#  '1123768ec4f958ddea9f8d865ee93af18a851f5a2861dd8de6dbb70e1b5336ab': ('0.6.1',
#                                                                       'AS',
#                                                                       '0.6.7',
#                                                                       'SuperDriveFx',
#                                                                       90),
#  '11ef2a2e51d1c644e10dfae6eb1513781581e2bd6eb0e35c436a7233eb882cd7': ('0.6.1',
#                                                                       'ErraticInstruments',
#                                                                       '0.6.1',
#                                                                       'MPEToCV',
#                                                                       150),
#  '122b7b99558a2063d861ad64274b6534cc0a9e7067d988afcf718c40390ca530': ('0.6.1',
#                                                                       'VultModules',
#                                                                       '0.6.3',
#                                                                       'Nopskate',
#                                                                       150),
#  '1267d60ac857c91e27daf9f92ec45743d740f2a0acc0bbe171f06db5b8763f59': ('0.6.1',
#                                                                       'dBiz',
#                                                                       '0.6.0',
#                                                                       'DualFilter',
#                                                                       240),
#  '126969ba847690b621ddc5c9a0606aa190d9aed0ee03ad4e568494f8311acbf9': ('0.6.1',
#                                                                       'RJModules',
#                                                                       '0.6.0',
#                                                                       'Randoms',
#                                                                       150),
#  '1272f583fe276e814e28c90523cd31675e74e53e332196cf3e884823b11d7870': ('0.6.1',
#                                                                       'PvC',
#                                                                       '0.6.0',
#                                                                       'Geighths',
#                                                                       60),
#  '127741dbfccc47c4b4988f2087bccb1e639814e4ba1a0e8cf57c02dc8d02e5e5': ('0.6.1',
#                                                                       'dBiz',
#                                                                       '0.6.0',
#                                                                       'Chord',
#                                                                       135),
#  '12dadaae06c3e5aa7196d810fa21a939edda45b2061b3adc9366b9cee8fe420e': ('0.6.1',
#                                                                       'mscHack',
#                                                                       '0.6.2',
#                                                                       'Mix_4x4_Stereo(2)',
#                                                                       705),
#  '13af5835083b7d978af369e550ed69394c181ab1869e59284a8897eb36cf0b85': ('0.6.1',
#                                                                       'Southpole-parasites',
#                                                                       '0.6.0',
#                                                                       'Splash',
#                                                                       120),
#  '13d3bba41e2773279f06105e60eaedd9777cbf58420b220b210372afec48eee5': ('0.6.1',
#                                                                       'HetrickCV',
#                                                                       '0.6.0',
#                                                                       'Scanner',
#                                                                       270),
#  '142c38e410cbb00de20d9712f6150ec4280757330dc22f4f3238364ad744f929': ('0.6.1',
#                                                                       'JW-Modules',
#                                                                       '0.6.1',
#                                                                       'GridSeq',
#                                                                       300),
#  '14a1cb412aabd21106019a216eec87971daf913b88336511643cc5a968770b33': ('0.6.1',
#                                                                       'AS-Drums-n-Filters',
#                                                                       '0.6.2',
#                                                                       'Drums8x8Percs',
#                                                                       60),
#  '1582846cbf74037d89f1fc14ba686caf2c786ec4444a266a8d39d9e44de8b575': ('0.6.1',
#                                                                       'ImpromptuModular',
#                                                                       '0.6.3',
#                                                                       'Phrase-Seq-16',
#                                                                       450),
#  '158353a006099d4ed9ae0ed74495beba24d9c4ec2ad9bec99ef76bf9d306f6f1': ('0.6.1',
#                                                                       'Fundamental',
#                                                                       '0.6.0',
#                                                                       'VCO',
#                                                                       150),
#  '15ca399712307bb8f4052f98b6ca9f106dd264dce8cc7b0fa90cd3e1a38fb671': ('0.6.1',
#                                                                       'NYSTHI',
#                                                                       '0.6.3',
#                                                                       'DualSignalDelayer',
#                                                                       30),
#  '15cb40092c92089cd97ce5d6bae3fecca9e618add7d7a739369f4aa79eb8c05e': ('0.6.1',
#                                                                       'Ohmer',
#                                                                       '0.6.4',
#                                                                       'OhmerBlank32',
#                                                                       480),
#  '162624ff69a24f625754ed2fa187617eb9937a624ae2736ff38360eaf6a7483e': ('0.6.1',
#                                                                       'Southpole',
#                                                                       '0.6.0',
#                                                                       'Smoke',
#                                                                       90),
#  '16cb62650e93401ba5475e47c203511e68436618f18ac9618ee8b5ee74fbdd51': ('0.6.1',
#                                                                       'VultModules',
#                                                                       '0.6.3',
#                                                                       'Vessek',
#                                                                       300),
#  '17a2ee016382aa224e934d306c329975eac2349a2490c1cb74c131773f6e1eb5': ('0.6.1',
#                                                                       'PG-Instruments',
#                                                                       '0.6.4',
#                                                                       'PGStereoVCF',
#                                                                       195),
#  '18145f1b52a6ff4da9625fd4b0bf620e6903fc026d77853dc14cc76e86078359': ('0.6.1',
#                                                                       'ML_modules',
#                                                                       '0.6.1',
#                                                                       'Counter',
#                                                                       90),
#  '1856b69524fcb8a1263a116694ceb0463488996a1076fcf76e738f5dcc3f1763': ('0.6.1',
#                                                                       'NYSTHI',
#                                                                       '0.6.3',
#                                                                       'complexSimpler',
#                                                                       105),
#  '188141c3a1669f4e7d9dfab0ab02301f51a5a846d3ee1ab8dd6a746e9002bb60': ('0.6.1',
#                                                                       'AnimatedCircuits_Panimated',
#                                                                       '0.6.1',
#                                                                       'ACPanimated',
#                                                                       75),
#  '18f3dc64583b645baa8bc583861b863d3f63d4d610031ea1e55e0b5a4bcc5609': ('0.6.1',
#                                                                       'AmalgamatedHarmonics',
#                                                                       '0.6.1',
#                                                                       'ScaleQuantizer',
#                                                                       240),
#  '196fc62de94a1a960894cd63c66a6c5eb274cf7a213496a24a597248828a3a82': ('0.6.1',
#                                                                       'cf',
#                                                                       '0.6.0',
#                                                                       'LEDS',
#                                                                       90),
#  '197ca45a934b3a2ef7b40bc10ae652fdaff1bad0b9e889d45262729a55ab8786': ('0.6.1',
#                                                                       'dBiz',
#                                                                       '0.6.0',
#                                                                       'Transpose',
#                                                                       60),
#  '197e6092a0e9bf967f9b636b38187fdfd6d04d16d5a8b85891f03419f05ae19e': ('0.6.1',
#                                                                       'alto777_LFSR',
#                                                                       '0.6.21',
#                                                                       'Amuse',
#                                                                       225),
#  '199ec2435745c58a0a391e9c2a90bb254c8c76ef623d0996c6477d0e43d19101': ('0.6.1',
#                                                                       'Bogaudio',
#                                                                       '0.6.6',
#                                                                       'Bogaudio-DGate',
#                                                                       45),
#  '1a2bd8883da878f1b65445e690f391142cb27822194c00dc31e71242cfdb79eb': ('0.6.1',
#                                                                       'luckyxxl',
#                                                                       '0.6.0',
#                                                                       'Tick',
#                                                                       90),
#  '1a7fa920dd2e0e26e30ad336b9b3e0cf30963c7bb6409a64fb57469c8afe8c1e': ('0.6.1',
#                                                                       'BaconMusic',
#                                                                       '0.6.2',
#                                                                       'ChipYourWave',
#                                                                       345),
#  '1a90922bda7f367f131f052f2aa689c837f4cef5c8cc5612f8006110954c99e1': ('0.6.1',
#                                                                       'Gratrix',
#                                                                       '0.6.0',
#                                                                       'Octave-G1',
#                                                                       180),
#  '1b1dd85f88c1ff77744449df411b541e751e3235457dc6e16473165d870dd78f': ('0.6.1',
#                                                                       'MSM',
#                                                                       '0.6.0',
#                                                                       'Rogue',
#                                                                       135),
#  '1b65cd660da582b911374b24d9356598b3de21ee635c28eeea33089948be8af6': ('0.6.1',
#                                                                       'HetrickCV',
#                                                                       '0.6.0',
#                                                                       'Exponent',
#                                                                       90),
#  '1c4837acddbca66c0008365eb88291e7eb7dc7c75fbdccb8007650673f14224d': ('0.6.1',
#                                                                       'LoopusModules',
#                                                                       '0.6.1',
#                                                                       'Foursome',
#                                                                       450),
#  '1c51270a2852faac82942f4174c143e93df178f52c562fb49d162fc37eb58441': ('0.6.1',
#                                                                       'SonusModular',
#                                                                       '0.6.1',
#                                                                       'Bymidside',
#                                                                       90),
#  '1c78451b3907bf1f661ca19a544e8a57c0e29e836b607a700e3fc0feb7b924e6': ('0.6.1',
#                                                                       'AmalgamatedHarmonics',
#                                                                       '0.6.1',
#                                                                       'Ruckus',
#                                                                       390),
#  '1c910e35e680fa76e00aabf7cd02247273b4cabc41d26adbb45228d37b2e14ff': ('0.6.1',
#                                                                       'Autodafe '
#                                                                       '- REDs',
#                                                                       '0.6.0',
#                                                                       '[S]NARE',
#                                                                       240),
#  '1d400ce0fe9c30fea898f5ef09098b01d2372289cc2cb52cd197c1f62eb028c2': ('0.6.1',
#                                                                       'Gratrix',
#                                                                       '0.6.0',
#                                                                       'VCA-F1',
#                                                                       180),
#  '1d5d655047c0c1aed0374813736e93bf5c0d1e2291c98e66b6187c4743faddce': ('0.6.1',
#                                                                       'AS-Seqs-n-Tools',
#                                                                       '0.6.1',
#                                                                       'ReBeat',
#                                                                       285),
#  '1da1fbba9d556fcb9281fda508f7786ed1ceb9f685791046196d236f58a1af38': ('0.6.1',
#                                                                       'Southpole',
#                                                                       '0.6.0',
#                                                                       'SNS',
#                                                                       90),
#  '1de23da36c5a412b7c8609d229eee9ad192cc45ad21bc342239c70e41b496a8d': ('0.6.1',
#                                                                       'RJModules',
#                                                                       '0.6.0',
#                                                                       'Displays',
#                                                                       150),
#  '1de6e79781b86bfe0fe65c9795e4b9dffce84e59c1639da07856445773228e2b': ('0.6.1',
#                                                                       'TheXOR',
#                                                                       '0.6.2',
#                                                                       'Mplex',
#                                                                       150),
#  '1e77bbfe9b75914fa592dd3cc52580725eaf8ecd0b7466bdabd53993045adafb': ('0.6.1',
#                                                                       'Koralfx-Modules',
#                                                                       '0.6.9',
#                                                                       'Quantovnik',
#                                                                       90),
#  '1ecffc8605c23ba60a4fb14e4e6dd68e2b01182c47da5635edb4cc8934c30dba': ('0.6.1',
#                                                                       'Valley',
#                                                                       '0.6.3',
#                                                                       'Topograph',
#                                                                       240),
#  '1ed6ee373b99f28504022c73299555d616f81658b0610b7bd6d50e6795178f9d': ('0.6.1',
#                                                                       'Southpole',
#                                                                       '0.6.0',
#                                                                       'Blank1HP',
#                                                                       15),
#  '1edef91aa9ab3cd769dee0ab5da6ac8230af01f9ca4d8566350493b334d46e03': ('0.6.1',
#                                                                       'HetrickCV',
#                                                                       '0.6.0',
#                                                                       'BlankPanel',
#                                                                       90),
#  '1f29b632f69289cf4a1aa4f10288f4068de53d8f7732f779fa281d6a4e70206a': ('0.6.1',
#                                                                       'Ohmer',
#                                                                       '0.6.4',
#                                                                       'RKDBRK',
#                                                                       120),
#  '1fb31b07e633bb66c8cfd429a85cc45b64fc30a0ba76f419b308f46cc85488a3': ('0.6.1',
#                                                                       'VultModules',
#                                                                       '0.6.3',
#                                                                       'Flux',
#                                                                       300),
#  '1fc047a01005f207e9a6522e60cd6ac1b1b0665c85bbcd7330ef9a9adb80fc7e': ('0.6.1',
#                                                                       'Valley',
#                                                                       '0.6.3',
#                                                                       'Dexter',
#                                                                       690),
#  '1fc6f78b8279fffb95a2cd65cd994abd0dde3466faf23aad96d04331c11877c6': ('0.6.1',
#                                                                       'RJModules',
#                                                                       '0.6.0',
#                                                                       'Filters',
#                                                                       120),
#  '1ff358cbb43ba1a2cef57595c44956b1799e80425364b9bdd77c9b29b4b27e69': ('0.6.1',
#                                                                       'Grayscale',
#                                                                       '0.6.0',
#                                                                       'Binary2',
#                                                                       90),
#  '214cdba397e7c4832bd6b34b03029944f3ee95fec561d4cf9f93155087b3ec53': ('0.6.1',
#                                                                       'ML_modules',
#                                                                       '0.6.1',
#                                                                       'TrigBuf',
#                                                                       60),
#  '21a1148877bb9852ffcfb239866e82b54780c8fa61bdd89cae6e574796a33cbe': ('0.6.1',
#                                                                       'ESeries',
#                                                                       '0.6.0',
#                                                                       'E340',
#                                                                       210),
#  '21e2e03faf35ea027c270bc07bb3007f919a8829c4548291a79d42d5eb7e0de4': ('0.6.1',
#                                                                       'SubmarineFree',
#                                                                       '0.6.3',
#                                                                       'BP-132',
#                                                                       480),
#  '22dda3bc208d509c67d1c0cea252fb3a1b359f224b99bbd136139b5f3210fdea': ('0.6.1',
#                                                                       'ML_modules',
#                                                                       '0.6.1',
#                                                                       'BPMdetect',
#                                                                       150),
#  '24627ec58fc9c225fa56d8924c0b6c58dba12fdc1712be5ad0b04d8e3f7abf0f': ('0.6.1',
#                                                                       'Alikins',
#                                                                       '0.6.0',
#                                                                       'MomentaryOnButtons',
#                                                                       60),
#  '246d2d7e7b46f9b66b15341638e9bc3bb8bb9a0d617318b412bb11932772217e': ('0.6.1',
#                                                                       'CharredDesert',
#                                                                       '0.6.0',
#                                                                       'Oscar',
#                                                                       90),
#  '2555fd1e2584ac39df6bf01720b1e96dc70137e7fd9ab78eb22741700c2e2f74': ('0.6.1',
#                                                                       'MSM',
#                                                                       '0.6.0',
#                                                                       'Random '
#                                                                       'Source',
#                                                                       120),
#  '25c9c110c4d121d5a03d4c043d236cf4314049629308563962dfde7841f3ee6c': ('0.6.1',
#                                                                       'AS-Drums-n-Filters',
#                                                                       '0.6.2',
#                                                                       'Drums8x8Hihats',
#                                                                       60),
#  '26d80eb8efa6973e1a80a3219fc2164190aa7286d01741f1304b2bf9c5b24759': ('0.6.1',
#                                                                       'NYSTHI',
#                                                                       '0.6.3',
#                                                                       'AttackDecay',
#                                                                       30),
#  '26fdbf5ec5422cf2bc00f02c9c286b3a0f1a2a026964088fe8d4e04ea94830ec': ('0.6.1',
#                                                                       'AudibleInstruments',
#                                                                       '0.6.0',
#                                                                       'Tides',
#                                                                       210),
#  '26fe5de3025038bd5be1566513122fb0f32118941c833d0f160159ea95db5937': ('0.6.1',
#                                                                       'NYSTHI',
#                                                                       '0.6.3',
#                                                                       'VectorMixer',
#                                                                       150),
#  '27ccaf8219df2a7bbb118af6ac3daf8efdf1d1b6d6e05b6704997f4862a9e4ee': ('0.6.1',
#                                                                       'LOGinstruments',
#                                                                       '0.6.0',
#                                                                       'Velvet',
#                                                                       150),
#  '27e8ba01a278512736c6be78b161eb5a09afe9d01e1789d62f44d699bbf746d9': ('0.6.1',
#                                                                       'mental',
#                                                                       '0.6.3',
#                                                                       'MentalCounters',
#                                                                       60),
#  '283b1c647cb30519ddc225ceee674c99791f60fa5be90dfb86258594fd4ac86e': ('0.6.1',
#                                                                       'AmalgamatedHarmonics',
#                                                                       '0.6.1',
#                                                                       'Progress',
#                                                                       390),
#  '286a332ef5510db9c4caa67f16d7290d1a5a9bdf841a874a45668a6bd37af3d9': ('0.6.1',
# ...
#                                                                       'HetrickCV',
#                                                                       '0.6.0',
#                                                                       'RandomGates',
#                                                                       180),
#  'f26261b1d8f993a1af4a62f416ce78ecd50597f8fd7af59821873ed688b76651': ('0.6.1',
#                                                                       'Ohmer',
#                                                                       '0.6.4',
#                                                                       'Metriks',
#                                                                       120),
#  'f29aae354b899fe6a12581a3875407a3242fa9ac7c901850ed9a1e00b6b83398': ('0.6.1',
#                                                                       'Blamsoft-XFXF35',
#                                                                       '0.6.0',
#                                                                       'Blamsoft-XFXF35',
#                                                                       210),
#  'f31eb8c8917f0a1988dd91758551465d7f7dfedcf9d35f9d0a13099b89ce7aa3': ('0.6.1',
#                                                                       'Gratrix',
#                                                                       '0.6.0',
#                                                                       'Blank9',
#                                                                       135),
#  'f34854ae3c9eafbc5df3d941d8d1acaa783a6838759e0d4fe37a6ad1e1e0f7a1': ('0.6.1',
#                                                                       'TheXOR',
#                                                                       '0.6.2',
#                                                                       'Boole',
#                                                                       210),
#  'f43cd4c15c9aaeddec99781f98cb11246f4b2c644b0a8f7f54025894a0b7b659': ('0.6.1',
#                                                                       'cf',
#                                                                       '0.6.0',
#                                                                       'DAVE',
#                                                                       120),
#  'f4524abde9f1648b2a1a9ae3d7c47723383a25a636c4b2b5ddbc3a5dbc6fd6c6': ('0.6.1',
#                                                                       'AnimatedCircuits_Panimated',
#                                                                       '0.6.1',
#                                                                       'ACFolding',
#                                                                       75),
#  'f50bb6c8548d0c1ea1cb3280e3302e95c3ca43efd52f9667d92772fa72488fd6': ('0.6.1',
#                                                                       'AS-Seqs-n-Tools',
#                                                                       '0.6.1',
#                                                                       'ReNote',
#                                                                       90),
#  'f50ef109c553dd23749a54fa1edb7d118919bddb49bdcd0183a2ee137c06bb12': ('0.6.1',
#                                                                       'Befaco',
#                                                                       '0.6.0',
#                                                                       'DualAtenuverter',
#                                                                       75),
#  'f5a26d0476404e85d89e06e8402e6fdce2966a4563b7df91624307686d682cfc': ('0.6.1',
#                                                                       'AS-Drums-n-Filters',
#                                                                       '0.6.2',
#                                                                       'DrumsC64Hihats',
#                                                                       60),
#  'f5b3ce56fc975c095c1ec06ceaeec0cb39f4f34614d1577914666f2f64e379fd': ('0.6.1',
#                                                                       'SonusModular',
#                                                                       '0.6.1',
#                                                                       'Luppolo',
#                                                                       90),
#  'f5d96962b548561c4aea17ebe659e0d9735af13bb78ca81794eab46d65e11075': ('0.6.1',
#                                                                       'AnimatedCircuits_Noises',
#                                                                       '0.6.0',
#                                                                       'ACNoises',
#                                                                       195),
#  'f5dbc8d22e6fb9ca5213689ec1162109ad50482001ff23fbbf4ec63a24cf47a3': ('0.6.1',
#                                                                       'BaconMusic',
#                                                                       '0.6.2',
#                                                                       'ChipNoise',
#                                                                       90),
#  'f5e4e6f0027991be5ad5de7e703a235e07793a27dbe98f86fb6f4b26a6321309': ('0.6.1',
#                                                                       'AS',
#                                                                       '0.6.7',
#                                                                       'Flow',
#                                                                       90),
#  'f660aa64edbc461bd9c96d835c892308ee9a833baaef11770d12b111249e78f4': ('0.6.1',
#                                                                       'VultModules',
#                                                                       '0.6.3',
#                                                                       'Splie',
#                                                                       45),
#  'f6e46cf3fa6e42f0c55f8ccdb0d700a946414d5df9e0a7a99a3b9e8c7aef6efc': ('0.6.1',
#                                                                       'PvC',
#                                                                       '0.6.0',
#                                                                       'Tails',
#                                                                       60),
#  'f6f1714b4db491df72870bad535e6a00ea86cf2718405bf1667a74438187293f': ('0.6.1',
#                                                                       'dBiz',
#                                                                       '0.6.0',
#                                                                       'Bene2',
#                                                                       300),
#  'f70557b9a3b9f88a7b8d5c538adbc8e2ca24036f915447c83bb5a22f9348c049': ('0.6.1',
#                                                                       'AS',
#                                                                       '0.6.7',
#                                                                       'TriLFO',
#                                                                       150),
#  'f75c9cde43d4609edc9714d993c2ff19049e960ac31e7484fc0bacd410b34be2': ('0.6.1',
#                                                                       'HetrickCV',
#                                                                       '0.6.0',
#                                                                       'Dust',
#                                                                       90),
#  'f7d7e542f25503ff2e2a1b4dbcac837e4dd3ca15ad52b739d5aafe531ad897fa': ('0.6.1',
#                                                                       'mental',
#                                                                       '0.6.3',
#                                                                       'MentalSums',
#                                                                       30),
#  'f857c966833c37f68d6dfff323cad686b3ae947fb46c5a424b711aee23bfea4f': ('0.6.1',
#                                                                       'RJModules',
#                                                                       '0.6.0',
#                                                                       'Volumes',
#                                                                       120),
#  'f910117ce5f988dc7ff991db12cdece186b1e2ba90eb8d7fc0b3f3cfb0ec99c1': ('0.6.1',
#                                                                       'LOGinstruments',
#                                                                       '0.6.0',
#                                                                       'Britix',
#                                                                       300),
#  'f94d83fbd814853b318bdc128636bf195c4d8ed6b8650b6bd6a5c3688ebf1a97': ('0.6.1',
#                                                                       'RB-Tilter',
#                                                                       '0.6.0',
#                                                                       'RB-Tilter',
#                                                                       90),
#  'f978c0f65a23105f03ce8bc8e3110c3b486c73306eeb1c9ac69e3b1fa3ecca6f': ('0.6.1',
#                                                                       'DHE-Modules',
#                                                                       '0.6.0',
#                                                                       'Upstage',
#                                                                       75),
#  'fa41c4942d2aa69fde97c9161c3544e4690768800f79beb00ac4858a736d2008': ('0.6.1',
#                                                                       'mental',
#                                                                       '0.6.3',
#                                                                       'MentalQuadLFO',
#                                                                       120),
#  'fb3d7de30d2a3a5ecfb90749f66c1e5071b48a64bfe695d11f4e7fad2d71ecdb': ('0.6.1',
#                                                                       'alto777_LFSR',
#                                                                       '0.6.21',
#                                                                       'YASeq3',
#                                                                       390),
#  'fb99fada893daf09dcb095d62b69c4f46e5f949fe1aff140a05769ff38011e8f': ('0.6.1',
#                                                                       'Core',
#                                                                       '0.6.1',
#                                                                       'MIDICCToCVInterface',
#                                                                       150),
#  'fbd755491e244e2d4251623499faef02dbcc1dce3fd97ee2da9d54c74395eae8': ('0.6.1',
#                                                                       'Koralfx-Modules',
#                                                                       '0.6.9',
#                                                                       'Nullovnik4',
#                                                                       60),
#  'fc5197cffbd82bac8f79f09b64c9e51f7a5682329a3cc50df66f32f40961310a': ('0.6.1',
#                                                                       'Alikins',
#                                                                       '0.6.0',
#                                                                       'SpecificValue',
#                                                                       90),
#  'fc57f13193ec3a0a2e40f16345d05a346ef0d34029ce5f0923c4793c6eead11a': ('0.6.1',
#                                                                       'Aepelzens '
#                                                                       'Modules',
#                                                                       '0.6.0dev',
#                                                                       'folder',
#                                                                       60),
#  'fc5f716b5d85a13d4d7de0841a38c76f77d0eb285938d64aa1ce44bb86445936': ('0.6.1',
#                                                                       'AudibleInstruments',
#                                                                       '0.6.0',
#                                                                       'Links',
#                                                                       60),
#  'fcb4d0cb2baf7fd88f9c295559e477ae8385402ea0dfab2f9011678451ab6a1c': ('0.6.1',
#                                                                       'NYSTHI',
#                                                                       '0.6.3',
#                                                                       'NYStereoChorus',
#                                                                       105),
#  'fcc6cdcbde2b0f01af141a642cb0e8e5d75ce1b3caa5d7dc5aa422d78c00fa1f': ('0.6.1',
#                                                                       'cf',
#                                                                       '0.6.0',
#                                                                       'MASTER',
#                                                                       90),
#  'fcf8596c8e27cb709cccb0ae8d82f5a5d4ee4594e8134fb6d1878d1b4b0f37ea': ('0.6.1',
#                                                                       'Southpole',
#                                                                       '0.6.0',
#                                                                       'Etagere',
#                                                                       90),
#  'fd6ada31313f69ca0394db5958aebf3c7dc215043851df1d8dcdd4dd82b21711': ('0.6.1',
#                                                                       'AS-Drums-n-Filters',
#                                                                       '0.6.2',
#                                                                       'Drums9x9Percs',
#                                                                       60),
#  'fdab442d6bb2a2839487a808d13060ebb362fac1a6a5e2b38f0a0cc623f451fb': ('0.6.1',
#                                                                       'DevilsHand',
#                                                                       '0.6.0',
#                                                                       'DevilsHand',
#                                                                       360),
#  'fdd69696ac80ec103819e5173c34026df7ab32c5b0632e18760d6cd0f2b017ce': ('0.6.1',
#                                                                       'Fundamental',
#                                                                       '0.6.0',
#                                                                       'ADSR',
#                                                                       120),
#  'fe7ebeb1f36210678e460e972d144f2e84ac85eee82071a56342fc1d8757ec13': ('0.6.1',
#                                                                       'KlirrFactory',
#                                                                       '0.6.0',
#                                                                       'Minus12dB',
#                                                                       60),
#  'fe9265a636ea0bef1d319e30d8bc00c722d307bbf01625278ece7df6746afe36': ('0.6.1',
#                                                                       'CharredDesert',
#                                                                       '0.6.0',
#                                                                       'Pan',
#                                                                       45),
#  'ff36e8b502005bb8b1d9d168701f15221cc4bd10b9258876e3bded33555b02a5': ('0.6.1',
#                                                                       'Koralfx-Modules',
#                                                                       '0.6.9',
#                                                                       'Mixovnik',
#                                                                       870)}

# %% [markdown]
# The **share** service for accepting catalog submissions accepts corpus models and merges them with the current shared corpus in the cloud. You **will be able to** submit this `cloud_share()` result to the cloud via `rackcli cloud --share` in an **upcoming rackcli release**.Here's are the merge mechanics.

# %%
def vet_share_corpus(c: List[Dict]) -> Tuple[Dict, Dict]:
    'verify and return valid and invalid corpus request, len(key)==64 and is_corpus_tuple(value)'
    def is_valid(v): return(len(v) == 5 and isinstance(v[0], str) and isinstance(v[1], str) and 
                            isinstance(v[2], str) and isinstance(v[3], str) and isinstance(v[4], int))
    return({k:v for k,v in c.items() if len(k) == 64 and is_valid(v)}, 
           {k:v for k,v in c.items() if not len(k) == 64 or not is_valid(v)})

def cloud_share(request, corpus):
    'merge request into corpus returning updated corpus and errors, add crowd validation, deploy serverless'
    request, errors = vet_share_corpus(request)
    {k:v for k, v in request.items() if k in corpus.keys()} # only add new plugin modules
    return({**corpus, **request}, errors)

c = dict(islice(corpus.items(), 0, 3))
r = {**dict(islice(corpus.items(), 2, 4)), **{'sha256(rv,ps,pv,ms)': ('rv', 3, 'pv', 'ms')}}
pp(c)
pp(r)
pp(cloud_share(r, c))
# Out:
# {'0668e58ce7a7aa49b5583aac63a2d73b2b45cf1de20efa5dc7351c4216cdd44d': ('0.6.1',
#                                                                       'Core',
#                                                                       '0.6.1',
#                                                                       'QuadMIDIToCVInterface',
#                                                                       150),
#  '30adfcb6a93f91a428fbe18703a910d249ab41279f8907d9911e54b655b1e75d': ('0.6.1',
#                                                                       'Core',
#                                                                       '0.6.1',
#                                                                       'AudioInterface',
#                                                                       150),
#  'bb47a317a2fec46ea5b7190b6caa72c8f38be0b8cd33a6d5fcd1fdc3ec48bec3': ('0.6.1',
#                                                                       'Core',
#                                                                       '0.6.1',
#                                                                       'MIDIToCVInterface',
#                                                                       120)}
# {'0668e58ce7a7aa49b5583aac63a2d73b2b45cf1de20efa5dc7351c4216cdd44d': ('0.6.1',
#                                                                       'Core',
#                                                                       '0.6.1',
#                                                                       'QuadMIDIToCVInterface',
#                                                                       150),
#  'fb99fada893daf09dcb095d62b69c4f46e5f949fe1aff140a05769ff38011e8f': ('0.6.1',
#                                                                       'Core',
#                                                                       '0.6.1',
#                                                                       'MIDICCToCVInterface',
#                                                                       150),
#  'sha256(rv,ps,pv,ms)': ('rv', 3, 'pv', 'ms')}
# ({'0668e58ce7a7aa49b5583aac63a2d73b2b45cf1de20efa5dc7351c4216cdd44d': ('0.6.1',
#                                                                        'Core',
#                                                                        '0.6.1',
#                                                                        'QuadMIDIToCVInterface',
#                                                                        150),
#   '30adfcb6a93f91a428fbe18703a910d249ab41279f8907d9911e54b655b1e75d': ('0.6.1',
#                                                                        'Core',
#                                                                        '0.6.1',
#                                                                        'AudioInterface',
#                                                                        150),
#   'bb47a317a2fec46ea5b7190b6caa72c8f38be0b8cd33a6d5fcd1fdc3ec48bec3': ('0.6.1',
#                                                                        'Core',
#                                                                        '0.6.1',
#                                                                        'MIDIToCVInterface',
#                                                                        120),
#   'fb99fada893daf09dcb095d62b69c4f46e5f949fe1aff140a05769ff38011e8f': ('0.6.1',
#                                                                        'Core',
#                                                                        '0.6.1',
#                                                                        'MIDICCToCVInterface',
#                                                                        150)},
#  {'sha256(rv,ps,pv,ms)': ('rv', 3, 'pv', 'ms')})

# %% [markdown]
# Here is the **sync** service wrapper (client and server) for looking up requested plugins in the cloud to "fix" your `catalog.partial.json`. It's possible that the requestor might have plugins installed that aren't known in the cloud corpus -- cloud_sync() will identify those as "unknowns" to be resolved appropriately.

# %%
request = ['hash1', 'hash2']
print(f'corpus request model: {request}')

def cloud_sync_partial_request(partial: Dict) -> List[str]:
    'corpus request for your catalog.partial.json, embed in rackcli'
    return([hash(partial['applicationVersion'], p['slug'], p['version'], m['slug']) \
            for p in partial['plugins'] for m in p['models']])

def vet_sync_corpus(request: List[str]) -> bool:
    return(all(isinstance(hash, str) and len(hash) == 64 for hash in request))

request = cloud_sync_partial_request(partial) + ['d00d'*16,] # include corpus unknow
pp(vet_sync_corpus(request))
# pp(request)
json.dump(request, open('/tmp/sync.json', 'w'), indent=2, ensure_ascii=False)

def cloud_sync(request: List[str], corpus: Dict) -> Tuple[List, List]:
    'request projected corpus and uknowns, deploy serverless'
    if not vet_sync_corpus(request): return({}, request)
    return(({k:v for k, v in corpus.items() if k in request}, 
           [r for r in request if not r in corpus.keys()]))

sync = cloud_sync(request, corpus)
print('unknowns:', sync[1])

# json.dump(request, open('/tmp/sync.json', 'w'), indent=2, ensure_ascii=False) # serialize for curl
# test: curl -X POST -H "Content-Type: application/json" -d @DATAFILE.JSON URL
# curl -X POST -H "Content-Type: application/json" -d @/tmp/sync.json https://9k564tm679.execute-api.us-east-1.amazonaws.com/dev/sync | jq
# Out:
# corpus request model: ['hash1', 'hash2']
# True
# unknowns: ['d00dd00dd00dd00dd00dd00dd00dd00dd00dd00dd00dd00dd00dd00dd00dd00d']

# %% [markdown]
# Lastly, let's "fix" our partial catalog with our response widths. "Unknowns" are currently ignored. This an cause issues if one later assumes all plugins have widths. Perhaps a prudent alternative would be to set "unknown"'s widths to an arbitrary values vs. so use cases accessing all plugin modules and assuming a valid width value will "sorta" work. If said arbitrary default was less than the actual width, the module might appear in a patch as trucated or overlaid by another module.
#
# If you're satisfied with the fixer() output, you could save it to `catalog.json` based on this processing of your `catalog.partial.json`.

# %%
def fixer(partial, sync):
    'sync the partial with width metadata, igore unknowns'
    for p in partial['plugins']:
        for m in p['models']:
            try: m['width'] = sync[0][hash(partial['applicationVersion'], p['slug'], p['version'], m['slug'])][4]
            except: pass # ignore "unknowns", would an arbitrary default be "better"?
    return(partial)

# pp(partial)
fixed = fixer(partial, sync)
# pp(fixed)
json.dump(fixed, open(rackdir + '/catalog.fixed.json', 'w'), indent=2, ensure_ascii=False)
# pp(fixed[:3]) # diff catalog.json catalog.fixed.json proves match!
